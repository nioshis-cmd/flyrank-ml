# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nioshis-cmd/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I chose Lane 1: Ranking Signal Analysis. I want to understand which safe search and content signals are associated with visibility, clicks, engagement, or movement. I chose this lane because it can be explored with simple comparisons and correlations using the starter dataset. It will help identify which signals are worth paying attention to, without assuming that any signal causes a change in Google rankings.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision is which signals are worth paying attention to when reviewing pages. A search or content analyst could use the findings to prioritize which signals to investigate further. A wrong recommendation could waste review time or lead someone to focus on a signal that is not actually useful.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", len(df))

corr = df["search_volume"].corr(df["impressions_90d"])
print(f"Correlation between search volume and impressions: {corr:.3f}")

print(f"Average CTR: {df['ctr'].mean():.3f}")
# Out:
# Number of rows: 30000
# Correlation between search volume and impressions: 0.001
# Average CTR: 0.511

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This work can identify observed relationships and directional patterns in the available data. It can provide decision-support about which signals may be worth investigating. It cannot prove that a signal causes a change in traffic or rankings, and it cannot predict or prove Google's algorithm. Any findings will be treated as observed and measured relationships, not causal conclusions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
