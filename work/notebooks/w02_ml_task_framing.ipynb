# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nioshis-cmd/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
# My lane is Ranking Signal Analysis. I frame this as a ranking/scoring problem because the goal is to identify and prioritize signals that are associated with page visibility, clicks, engagement, or movement. The output would help an analyst decide which signals are worth investigating first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
# For this initial framing, I will use page performance measures such as impressions, CTR, and trend direction as observable outcomes/proxies. The goal is to study which available signals are associated with these outcomes rather than claim that they cause them.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
# I will use correlation, grouped comparisons, and effect sizes to measure the strength of relationships between signals and outcomes. The useful result is a clear, interpretable relationship that can support a content decision, rather than simply maximizing model accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Shape:", df.shape)
display(df[[
    "content_id",
    "client_id",
    "impressions_90d",
    "ctr",
    "avg_position",
    "trend_direction"
]].head())
# Out:
# Shape: (30000, 44)
#              content_id          client_id  impressions_90d   ctr  \
# 0  content_304f48230142  client_f369cb89fc             3803  0.76
# 1  content_a1fb4e703a9e  client_4e07408562            15320  0.05
# 2  content_9aa793d4d895  client_7f2253d7e2            12581  0.09
# 3  content_331d6c4de07b  client_19581e27de            11751  0.49
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140  0.13
#
#    avg_position trend_direction
# 0          10.6            down
# 1          20.3            down
# 2          36.5            down
# 3           6.2          stable
# 4          44.0            down

# %% [markdown]
# Unit of analysis: one content page. Each row represents one content item with its observed search and performance signals over the available window.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
# A fixed rule may be useful as a simple baseline, but it requires manually choosing thresholds and may miss combinations of signals. ML or statistical analysis can examine several signals together and identify patterns that a single rule may not capture. I would only prefer the more complex approach if it produces a useful and validated improvement over a simple baseline.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
