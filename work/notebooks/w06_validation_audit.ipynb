# %% [markdown]
# # ML-09 — Validation and Research Claim Audit
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nioshis-cmd/flyrank-ml-internship/blob/main/work/notebooks/w06_validation_audit.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Two paper findings + my methodology questions
#
# *Pick two findings from the FlyRank research paper. For each: where does the label come from, and does the validation design carry the claim? Constructive tone.*
#
# One finding I would examine is the relationship between content freshness and search performance. The label should come from an observed change in the relevant search-performance outcome, rather than from the feature itself. My methodology question is whether the validation design keeps the information used to create the label separate from the information available at the decision point.
#
# A second finding I would examine is the relationship between search visibility signals such as impressions, position, and CTR and content performance. Again, the label should represent an observed outcome measured after the feature window. My methodology question is whether the validation split prevents pages from the same client appearing in both training and evaluation, so that the result is not overly optimistic.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. My model under an honest split (before/after)
#
# *Re-run your Week-5 model under a grouped or time-aware split. Show both numbers.*
#
# I will re-run my Week-5 Decision Tree using a client-holdout split. The baseline and model will be evaluated on the same held-out clients using Precision@50. I will compare the results before and after the honest split and report the measured numbers rather than assuming that the model will perform better.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Leakage audit
#
# *The same hunt from Week 3, on your final feature set.*
#
# I checked the final feature set for leakage. The features should only contain information that would have been available at the decision moment. I will exclude the target label, future-window measurements, and any product decision flags or label-derived columns. The final model should therefore be evaluated using only information available before the outcome being measured.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Claim rewrite
#
# *Take your own boldest sentence and rewrite it in safe language: observed, measured, directional, decision-support.*
#
# My strongest claim will be written as a measured and directional finding rather than a causal claim. The model and baseline can be compared on the held-out data to determine which approach produced higher Precision@50 in this evaluation. This result supports content prioritization and decision-support, but it does not prove that the model causes pages to improve or predict Google's ranking algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
