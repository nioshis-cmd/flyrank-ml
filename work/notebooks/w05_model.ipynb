# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/nioshis-cmd/flyrank-ml-internship/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*
#
# I will use a Random Forest model because it can learn non-linear relationships between search signals such as impressions, clicks, CTR, and average position. It fits my lane because I want to rank content opportunities rather than use only one fixed threshold. The model will be used as decision-support, not as proof of causation.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*
#
# I will use a client-holdout split. Pages from the same client should not appear in both training and test data because that could make the evaluation look better than it really is. The model will learn from one group of clients and be evaluated on different clients. This gives a more honest estimate of how the ranking approach may work on unseen clients.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*
#
# I will train the Decision Tree using the training clients and evaluate it on the held-out clients. I will compare the model with my Week-4 hand rule using Precision@50, because the practical goal is to put useful pages near the top of a review queue. Both methods will be evaluated on the same client-holdout test set.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*
#
# The model will still make mistakes. Some pages that receive a high score may not actually be declining, while some declining pages may receive a lower score. This can happen because the available search signals do not contain every factor affecting page performance. I will therefore treat the model score as a prioritization signal for human review rather than an automatic decision.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
